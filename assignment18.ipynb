# %%
#Solution

# %%
#Q1.

print('''
        Flask is a microframework for developers, designed to enable them to create and scale web apps quickly and simply. 
        Explaining how they go about doing that will take a little more unraveling.
        
        
        Flask is a web framework, it’s a Python module that lets you develop web applications easily. 
        It’s has a small and easy-to-extend core: it’s a microframework that doesn’t include an 
        ORM (Object Relational Manager) or such features.

        It does have many cool features like url routing, template engine. It is a WSGI web app framework.
        
        
        Advantages of Flask

            . Scalable. Size is everything, and Flask's status as a microframework means that you can use 
            it to grow a tech project such as a web app incredibly quickly.
            
            . Flexible.
            
            . Easy to negotiate.  
            
            . Lightweight.  
            
            . Documentation. 
            
            . Not a lot of tools.  
            
            . Difficult to get familiar with a larger Flask app.  
            
            . Maintenance costs.
        

''')
# Out:
#         Flask is a microframework for developers, designed to enable them to create and scale web apps quickly and simply.
#         Explaining how they go about doing that will take a little more unraveling.
#
#
#         Flask is a web framework, it’s a Python module that lets you develop web applications easily.
#         It’s has a small and easy-to-extend core: it’s a microframework that doesn’t include an
#         ORM (Object Relational Manager) or such features.
#
#         It does have many cool features like url routing, template engine. It is a WSGI web app framework.
#
#
#         Advantages of Flask
#
#             . Scalable. Size is everything, and Flask's status as a microframework means that you can use
#             it to grow a tech project such as a web app incredibly quickly.
#
#             . Flexible.
#
#             . Easy to negotiate.
#
#             . Lightweight.
#
#             . Documentation.
#
#             . Not a lot of tools.
#
# ...

# %%
#Q2

print('''
        
        from flask import Flask
        app=Flask(__name__)
        @app.route("/hello_world")
        def hello_world():
            return "<h1>Hello World!!</h1>"
        if __name__=="__main__":
            app.run(host="0.0.0.0")

''')
# Out:
#
#         from flask import Flask
#         app=Flask(__name__)
#         @app.route("/hello_world")
#         def hello_world():
#             return "<h1>Hello World!!</h1>"
#         if __name__=="__main__":
#             app.run(host="0.0.0.0")

# %% [markdown]
# ![Screenshot%20%286%29.png](attachment:Screenshot%20%286%29.png)

# %%
#Q3.

print('''
        App Routing means mapping the URLs to a specific function that will handle the logic for that URL.
        or
        App routing is the technique used to map the specific URL with the associated function intended to perform some task
        
        
        use:
        App routing is used to map the specific URL with the associated function that is intended to perform some task. 
        It is used to access some particular page like Flask Tutorial in the web application.
        
        app=Flask(__name__)
        @app.route("/")
        def fun():
            return "loop"
        
        
        
        
        ''')
# Out:
#         App Routing means mapping the URLs to a specific function that will handle the logic for that URL.
#         or
#         App routing is the technique used to map the specific URL with the associated function intended to perform some task
#
#
#         use:
#         App routing is used to map the specific URL with the associated function that is intended to perform some task.
#         It is used to access some particular page like Flask Tutorial in the web application.
#
#         app=Flask(__name__)
#         @app.route("/")
#         def fun():
#             return "loop"

# %%
#Q4.

print('''
        from flask import Flask
        app=Flask(__name__)
        @app.route("/welcome")
        def welcome():
            return "Welcome to ABC Corporation"
        
        if __name__=="__main__":
            app.run(host="0.0.0.0")

''')
# Out:
#         from flask import Flask
#         app=Flask(__name__)
#         @app.route("/welcome")
#         def welcome():
#             return "Welcome to ABC Corporation"
#
#         if __name__=="__main__":
#             app.run(host="0.0.0.0")

# %% [markdown]
# ![Screenshot%20%287%29.png](attachment:Screenshot%20%287%29.png)

# %%
print('''
        from flask import Flask
        app=Flask(__name__)
        @app.route("/")
        def coop():
            return """<h1><pre>
            Company Name: ABC Corporation
            Location: India
            Contact Detail: 999-999-9999</pre></h1>"""
            
        
        if __name__=="__main__":
            app.run(host="0.0.0.0")
        
        

''')
# Out:
#         from flask import Flask
#         app=Flask(__name__)
#         @app.route("/")
#         def coop():
#             return """<h1><pre>
#             Company Name: ABC Corporation
#             Location: India
#             Contact Detail: 999-999-9999</pre></h1>"""
#
#
#         if __name__=="__main__":
#             app.run(host="0.0.0.0")

# %% [markdown]
# ![Screenshot%20%288%29.png](attachment:Screenshot%20%288%29.png)

# %%
#Q5.
print('''
        URL Building
        To build a URL to a specific function, use the url_for() function. 
        It accepts the name of the function as its first argument and any number of keyword arguments,
        each corresponding to a variable part of the URL rule.
        
        from flask import url_for, Flask
        appFlask = Flask(__name__)
        @appFlask.route('/home')
        def home():
           return 'We are in Home Page!'
        with appFlask.test_request_context():
            print(url_for('login'))
        

''')
# Out:
#         URL Building
#         To build a URL to a specific function, use the url_for() function.
#         It accepts the name of the function as its first argument and any number of keyword arguments,
#         each corresponding to a variable part of the URL rule.
#
#         from flask import url_for, Flask
#         appFlask = Flask(__name__)
#         @appFlask.route('/home')
#         def home():
#            return 'We are in Home Page!'
#         with appFlask.test_request_context():
#             print(url_for('login'))
